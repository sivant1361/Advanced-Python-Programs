# %%
import matplotlib.pyplot as p
# %matplotlib inline

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]

# %%
p.xlabel("x-axis")
p.ylabel("y-axis")
p.title("Testing")
p.subplot(1,2,1)
p.plot(x,y,"--",marker="o")
p.subplot(1,2,2)
p.plot(x,y,"pink",marker="o")
