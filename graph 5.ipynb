# %%
import seaborn as s
import numpy as n
# %matplotlib inline

# %%
t=s.load_dataset("tips")

# %%
t.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
s.barplot(t["tip"].head(10),t["total_bill"].head(10))

# %%
s.barplot(x="day",y="total_bill",data=t)

# %%
s.countplot(t["sex"])

# %%
s.boxplot(x="day",y="total_bill",data=t,hue="sex")

# %%
s.boxplot(t["day"],t["total_bill"])

# %%
s.violinplot(x="day",y="total_bill",data=t)

# %%
s.violinplot(x="day",y="total_bill",data=t,hue="smoker",split=True)

# %%
s.violinplot(x="day",y="total_bill",data=t,hue="sex")
