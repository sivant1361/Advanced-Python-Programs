# %%
import pandas as pd

# %%
r=pd.read_csv("weather1.csv",header=None)

# %%
r
# Out:
#              0             1           2               3
# 0          Day  Temperature   Wind Speed           Event
# 1   01-01-2018            35         320           Rainy
# 2   02-01-2018            28         123           cloud
# 3   03-01-2018            26         156             Hot
# 4   04-01-2018            29         174  not available
# 5   05-01-2018            30         185           Rainy
# 6   06-01-2018            31         169           cloud
# 7   07-01-2018            32         245             Hot
# 8   08-01-2018            35         123  not available
# 9   09-01-2018            40         156           cloud
# 10  10-01-2018            22         147             Hot
# 11  11-01-2018            35         563  not available
# 12  12-01-2018            28         156           cloud
# 13  13-01-2018            24         412             Hot
# 14  14-01-2018            26         457           Rainy
# 15  01-02-2018            32         423           cloud
# ...

# %%
r.to_csv("nweather.csv")

# %%
r=pd.read_excel("weather.xlsx")

# %%
r
# Out:
#           Day  Temperature   Wind Speed           Event
# 0  2018-01-01            35         320           Rainy
# 1  2018-01-02            28         123           cloud
# 2  2018-01-03            26         156             Hot
# 3  2018-01-04            29         174  not available
# 4  2018-01-05            30         185           Rainy
# 5  2018-01-06            31         169           cloud
# 6  2018-01-07            32         245             Hot
# 7  2018-01-08            35         123  not available
# 8  2018-01-09            40         156           cloud
# 9  2018-01-10            22         147             Hot
# 10 2018-01-11            35         563  not available
# 11 2018-01-12            28         156           cloud
# 12 2018-01-13            24         412             Hot
# 13 2018-01-14            26         457           Rainy
# 14 2018-02-01            32         423           cloud
# 15 2018-02-02            35         156             Hot
# ...

# %%
import numpy as n
def pc(cell):
    if(cell==n.nan):
        return "not available"
    return cell

# %%
r=pd.read_excel("weather.xlsx","weather1",converters={"Event":pc})

# %%
r
# Out:
#           Day  Temperature   Wind Speed           Event
# 0  2018-01-01            35         320           Rainy
# 1  2018-01-02            28         123           cloud
# 2  2018-01-03            26         156             Hot
# 3  2018-01-04            29         174  not available
# 4  2018-01-05            30         185           Rainy
# 5  2018-01-06            31         169           cloud
# 6  2018-01-07            32         245             Hot
# 7  2018-01-08            35         123  not available
# 8  2018-01-09            40         156           cloud
# 9  2018-01-10            22         147             Hot
# 10 2018-01-11            35         563  not available
# 11 2018-01-12            28         156           cloud
# 12 2018-01-13            24         412             Hot
# 13 2018-01-14            26         457           Rainy
# 14 2018-02-01            32         423           cloud
# 15 2018-02-02            35         156             Hot
# ...

# %%
r.to_excel("nweather1.xlsx",sheet_name="New Weather")

# %%
a={"rollno":[1,2,3,4,5],"name":["sivant","siva","starr","king","cashew"]}

# %%
a
# Out:
# {'rollno': [1, 2, 3, 4, 5],
#  'name': ['sivant', 'siva', 'starr', 'king', 'cashew']}

# %%
ai=pd.DataFrame(a)

# %%
ai
# Out:
#    rollno    name
# 0       1  sivant
# 1       2    siva
# 2       3   starr
# 3       4    king
# 4       5  cashew

# %%
with pd.ExcelWriter("AI1.xlsx") as p:
    ai.to_excel(p,sheet_name="AI")

# %%
import numpy as np

# %%
df=pd.DataFrame(np.random.randint(1,100),index=['a','c','e','g','i'],columns=["one","two","three"])

# %%
df=df.reindex(['a','b','c','d','e','f','g','h','i'])

# %%
df
# Out:
#     one   two  three
# a  33.0  33.0   33.0
# b   NaN   NaN    NaN
# c  33.0  33.0   33.0
# d   NaN   NaN    NaN
# e  33.0  33.0   33.0
# f   NaN   NaN    NaN
# g  33.0  33.0   33.0
# h   NaN   NaN    NaN
# i  33.0  33.0   33.0

# %%
list=[["E1",1],["E2",2],["E3",3]]

# %%
ldf=pd.DataFrame(list,index=[1,2,3],columns=["Clg_No","RollNo"])

# %%
ldf
# Out:
#   Clg_No  RollNo
# 1     E1       1
# 2     E2       2
# 3     E3       3

# %%
ldf=ldf.reindex([1,2,3,4,5,6])

# %%
ldf
# Out:
#   Clg_No  RollNo
# 1     E1     1.0
# 2     E2     2.0
# 3     E3     3.0
# 4    NaN     NaN
# 5    NaN     NaN
# 6    NaN     NaN

# %%
print(ldf.fillna(0))
# Out:
#   Clg_No  RollNo
# 1     E1     1.0
# 2     E2     2.0
# 3     E3     3.0
# 4      0     0.0
# 5      0     0.0
# 6      0     0.0

# %%
len(ldf)
# Out:
# 6

# %%
ldf["Clg_No"][7]=7
# Out:
# C:\Users\Sivant\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ldf
# Out:
#   Clg_No  RollNo
# 1     E1     1.0
# 2     E2     2.0
# 3     E3     3.0
# 4    NaN     NaN
# 5    NaN     NaN
# 6    NaN     NaN

# %%
print(ldf.dropna())
# Out:
#   Clg_No  RollNo
# 1     E1     1.0
# 2     E2     2.0
# 3     E3     3.0

# %%
ldf
# Out:
#   Clg_No  RollNo
# 1     E1     1.0
# 2     E2     2.0
# 3     E3     3.0
# 4    NaN     NaN
# 5    NaN     NaN
# 6    NaN     NaN

# %%
print(ldf.replace({1:1000,2:2000}))
# Out:
#   Clg_No  RollNo
# 1     E1  1000.0
# 2     E2  2000.0
# 3     E3     3.0
# 4    NaN     NaN
# 5    NaN     NaN
# 6    NaN     NaN
